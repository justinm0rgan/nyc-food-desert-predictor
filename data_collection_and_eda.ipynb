# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import censusdata

# %% [markdown]
# ### Retail Food Stores data

# %%
# from sodapy import Socrata

# # Unauthenticated client only works with public data sets. Note 'None'
# # in place of application token, and no username or password:
# client = Socrata("data.ny.gov", app_token='2zRBf7lHUfSBGGX44PZy1XhmT')



# # Results returned as JSON from API / converted to Python list of
# # dictionaries by sodapy.
# store_df = client.get("9a8c-vfzj", limit=20000, 
#           where='county="Kings" OR county="New York" OR county="Queens" OR county="Bronx" OR county="Richmond"')

# # Convert to pandas DataFrame
# store_df = pd.DataFrame.from_records(store_df)

# %% [markdown]
# ### USDA data import

# %%
# import usa dataset
usda_df = pd.read_excel('data/usda/DataDownload2015.xlsx', sheet_name='Food Access Research Atlas', header=0)
usda_data_dict = pd.read_excel('data/usda/DataDownload2015.xlsx', sheet_name='Variable Lookup')

# %%
usda_df.head()
# Out:
#    CensusTract    State   County  Urban  POP2010  OHU2010  GroupQuartersFlag  \
# 0   1001020100  Alabama  Autauga      1     1912      693                  0
# 1   1001020200  Alabama  Autauga      1     2170      743                  0
# 2   1001020300  Alabama  Autauga      1     3373     1256                  0
# 3   1001020400  Alabama  Autauga      1     4386     1722                  0
# 4   1001020500  Alabama  Autauga      1    10766     4082                  0
#
#    NUMGQTRS  PCTGQTRS  LILATracts_1And10  ...  TractSeniors  TractWhite  \
# 0         0  0.000000                  0  ...           221        1622
# 1       181  0.083410                  0  ...           214         888
# 2         0  0.000000                  0  ...           439        2576
# 3         0  0.000000                  0  ...           904        4086
# 4       181  0.016812                  0  ...          1126        8666
#
# ...

# %%
pd.options.display.max_rows = None
pd.options.display.max_columns = None
pd.set_option('display.max_colwidth', -1)
usda_data_dict
# Out:
#                     Field  \
# 0    CensusTract
# 1    State
# 2    County
# 3    Urban
# 4    POP2010
# 5    OHU2010
# 6    GroupQuartersFlag
# 7    NUMGQTRS
# 8    PCTGQTRS
# 9    LILATracts_1And10
# 10   LILATracts_halfAnd10
# 11   LILATracts_1And20
# 12   LILATracts_Vehicle
# 13   HUNVFlag
# 14   LowIncomeTracts
# 15   PovertyRate
# 16   MedianFamilyIncome
# 17   LA1and10
# 18   LAhalfand10
# 19   LA1and20
# 20   LATracts_half
# 21   LATracts1
# 22   LATracts10
# 23   LATracts20
# 24   LATractsVehicle_20
# 25   LAPOP1_10
# 26   LAPOP05_10
# 27   LAPOP1_20
# 28   LALOWI1_10
# 29   LALOWI05_10
# 30   LALOWI1_20
# 31   lapophalf
# 32   lapophalfshare
# 33   lalowihalf
# 34   lalowihalfshare
# 35   lakidshalf
# 36   lakidshalfshare
# 37   laseniorshalf
# 38   laseniorshalfshare
# 39   lawhitehalf
# 40   lawhitehalfshare
# 41   lablackhalf
# 42   lablackhalfshare
# 43   laasianhalf
# 44   laasianhalfshare
# 45   lanhopihalf
# 46   lanhopihalfshare
# 47   laaianhalf
# ...

# %%
usda_df = usda_df.loc[usda_df['State'] == 'New York']

# %%
five_boroughs =  (usda_df['County'] == 'Bronx') | (usda_df['County'] == 'Kings') | (usda_df['County'] == 'New York') |\
        (usda_df['County'] == 'Queens') | (usda_df['County'] == 'Richmond')
         
usda_df = usda_df.loc[five_boroughs]

# %%
usda_df.shape
# Out:
# (2165, 147)

# %%
usda_df['County'].value_counts()
# Out:
# Kings       760
# Queens      669
# Bronx       339
# New York    288
# Richmond    109
# Name: County, dtype: int64

# %%
usda_df['LILATracts_halfAnd10'].value_counts()
# Out:
# 0    2134
# 1    31
# Name: LILATracts_halfAnd10, dtype: int64

# %%
nyc_food_desert = usda_df['LILATracts_halfAnd10'] == 1
nyc_food_desert_df = usda_df.loc[nyc_food_desert]
nyc_food_desert_df.shape
# Out:
# (31, 147)

# %%
usda_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2165 entries, 43145 to 47000
# Columns: 147 entries, CensusTract to TractSNAP
# dtypes: float64(112), int64(33), object(2)
# memory usage: 2.4+ MB
